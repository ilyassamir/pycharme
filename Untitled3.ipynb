# %% [markdown]
# # Travail préparé par Samir Ilyas

# %%
# importations des librairies
import plotly.offline as py
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.figure_factory as create_table 
import plotly as ppy
import plotly.express as px
import pandas as pd
import numpy as np
import plotly.express as px

# %%
#lecture de données
df1 = pd.read_csv('AAPL.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       757 non-null    object
#  1   Open       757 non-null    float64
#  2   High       757 non-null    float64
#  3   Low        757 non-null    float64
#  4   Close      757 non-null    float64
#  5   Adj Close  757 non-null    float64
#  6   Volume     757 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 41.5+ KB

# %%
# quelques graphes
fig5=px.line(df1, x = 'Date' , y ='Close', title ='Close ')
fig5.show()
# Out:
# <div>                            <div id="349b8826-23bc-454b-8b70-5d97ddcd5fda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("349b8826-23bc-454b-8b70-5d97ddcd5fda")) {                    Plotly.newPlot(                        "349b8826-23bc-454b-8b70-5d97ddcd5fda",                        [{"hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2015-10-13","2015-10-14","2015-10-15","2015-10-16","2015-10-19","2015-10-20","2015-10-21","2015-10-22","2015-10-23","2015-10-26","2015-10-27","2015-10-28","2015-10-29","2015-10-30","2015-11-02","2015-11-03","2015-11-04","2015-11-05","2015-11-06","2015-1
# ...

# %% [markdown]
# On constate que la série 'Close' est croissante en fonction de temps .

# %%
Propriétés_statistiques =df1.iloc[:,4:5].describe()
Propriétés_statistiques
# Out:
#             Close
# count  757.000000
# mean    35.686275
# std      9.098641
# min     22.584999
# 25%     27.487499
# 50%     35.875000
# 75%     42.817501
# max     58.017502

# %% [markdown]
# on remarque que notre série a une moyenne de 35,68 et un écart-type de 9.09 c'est à dir un variance de 82,62 .

# %%
#pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.stattools import adfuller

#perform augmented Dickey-Fuller test
adfuller(df1['Close'])
# Out:
# (0.7769356029856658,
#  0.9912545941576599,
#  8,
#  748,
#  {'1%': -3.43912257105195,
#   '5%': -2.8654117005229844,
#   '10%': -2.568831705010152},
#  1062.5132041847057)

# %% [markdown]
# puisque la P-value est supériure de 0,05 , Alors la série Close est significativement non stationnaire .

# %%
list1=[i for i in range(756) ]
len(list1)
# Out:
# 756

# %%
list1=[i for i in range(756) ]
len(list1)
df2 = df1.iloc[1:,4:5]
df2.index =list1
df3 = df1.iloc[:,4:5]
rendement = (df3 - df2) / df3
R = rendement.iloc[:755]

# %%
R
# Out:
#         Close
# 0    0.014134
# 1   -0.014971
# 2    0.007331
# 3   -0.006214
# 4   -0.018258
# ..        ...
# 750  0.016229
# 751  0.002318
# 752 -0.013853
# 753  0.046326
# 754  0.008828
#
# [755 rows x 1 columns]

# %%
R.describe()
# Out:
#             Close
# count  755.000000
# mean    -0.000958
# std      0.013801
# min     -0.064963
# 25%     -0.007837
# 50%     -0.000667
# 75%      0.005590
# max      0.065707

# %% [markdown]
# on voit que la moyenne du rendement est négative et presque nulle et l'ecart type égale à 0.01

# %%
adfuller(R)
# Out:
# (-25.984015171173453,
#  0.0,
#  0,
#  754,
#  {'1%': -3.439052522969989,
#   '5%': -2.8653808299915013,
#   '10%': -2.5688152592363274},
#  -4216.677219626488)

# %% [markdown]
# puisque la P-value est inférieure de 0,05 , Alors la série Rendement  est significativement stationnaire .
